# %%
pip install langchain
# Out:
# Collecting langchain
#   Downloading langchain-0.2.16-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: PyYAML>=5.3 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from langchain) (2.0.32)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain)
#   Downloading aiohttp-3.10.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.5 kB)
# Collecting async-timeout<5.0.0,>=4.0.0 (from langchain)
#   Downloading async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Collecting langchain-core<0.3.0,>=0.2.38 (from langchain)
#   Downloading langchain_core-0.2.38-py3-none-any.whl.metadata (6.2 kB)
# Collecting langchain-text-splitters<0.3.0,>=0.2.0 (from langchain)
#   Downloading langchain_text_splitters-0.2.4-py3-none-any.whl.metadata (2.3 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain)
#   Downloading langsmith-0.1.116-py3-none-any.whl.metadata (13 kB)
# Collecting numpy<2,>=1 (from langchain)
#   Downloading numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Requirement already satisfied: pydantic<3,>=1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from langchain) (2.8.2)
# Requirement already satisfied: requests<3,>=2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from langchain) (2.32.3)
# Collecting tenacity!=8.4.0,<9.0.0,>=8.1.0 (from langchain)
#   Downloading tenacity-8.5.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading aiohappyeyeballs-2.4.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs>=17.3.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.2.0)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading frozenlist-1.4.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading multidict-6.0.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading yarl-1.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (45 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.3.0,>=0.2.38->langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: packaging<25,>=23.2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from langchain-core<0.3.0,>=0.2.38->langchain) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from langchain-core<0.3.0,>=0.2.38->langchain) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (0.27.2)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.17->langchain)
#   Downloading orjson-3.10.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (50 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pydantic<3,>=1->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pydantic<3,>=1->langchain) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from requests<3,>=2->langchain) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from requests<3,>=2->langchain) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from requests<3,>=2->langchain) (2024.7.4)
# Requirement already satisfied: greenlet!=0.4.17 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Requirement already satisfied: anyio in /srv/conda/envs/notebook/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (4.4.0)
# Requirement already satisfied: httpcore==1.* in /srv/conda/envs/notebook/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.0.5)
# Requirement already satisfied: sniffio in /srv/conda/envs/notebook/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.38->langchain) (3.0.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.2.2)
# Downloading langchain-0.2.16-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 4.5 MB/s eta 0:00:00a 0:00:01
# Downloading aiohttp-3.10.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 4.5 MB/s eta 0:00:00a 0:00:01
# Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Downloading langchain_core-0.2.38-py3-none-any.whl (396 kB)
# Downloading langchain_text_splitters-0.2.4-py3-none-any.whl (25 kB)
# Downloading langsmith-0.1.116-py3-none-any.whl (290 kB)
# Downloading numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 4.2 MB/s eta 0:00:00a 0:00:01
# Downloading tenacity-8.5.0-py3-none-any.whl (28 kB)
# Downloading aiohappyeyeballs-2.4.0-py3-none-any.whl (12 kB)
# Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Downloading frozenlist-1.4.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (239 kB)
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading multidict-6.0.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (124 kB)
# Downloading orjson-3.10.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (141 kB)
# Downloading yarl-1.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (469 kB)
# Installing collected packages: tenacity, orjson, numpy, multidict, jsonpatch, frozenlist, async-timeout, aiohappyeyeballs, yarl, aiosignal, langsmith, aiohttp, langchain-core, langchain-text-splitters, langchain
# Successfully installed aiohappyeyeballs-2.4.0 aiohttp-3.10.5 aiosignal-1.3.1 async-timeout-4.0.3 frozenlist-1.4.1 jsonpatch-1.33 langchain-0.2.16 langchain-core-0.2.38 langchain-text-splitters-0.2.4 langsmith-0.1.116 multidict-6.0.5 numpy-1.26.4 orjson-3.10.7 tenacity-8.5.0 yarl-1.10.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install langchain-openai
# Out:
# Collecting langchain-openai
#   Downloading langchain_openai-0.1.23-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.35 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from langchain-openai) (0.2.38)
# Collecting openai<2.0.0,>=1.40.0 (from langchain-openai)
#   Downloading openai-1.44.0-py3-none-any.whl.metadata (22 kB)
# Collecting tiktoken<1,>=0.7 (from langchain-openai)
#   Downloading tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: PyYAML>=5.3 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from langchain-core<0.3.0,>=0.2.35->langchain-openai) (6.0.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from langchain-core<0.3.0,>=0.2.35->langchain-openai) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.75 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from langchain-core<0.3.0,>=0.2.35->langchain-openai) (0.1.116)
# Requirement already satisfied: packaging<25,>=23.2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from langchain-core<0.3.0,>=0.2.35->langchain-openai) (24.1)
# Requirement already satisfied: pydantic<3,>=1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from langchain-core<0.3.0,>=0.2.35->langchain-openai) (2.8.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from langchain-core<0.3.0,>=0.2.35->langchain-openai) (8.5.0)
# Requirement already satisfied: typing-extensions>=4.7 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from langchain-core<0.3.0,>=0.2.35->langchain-openai) (4.12.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from openai<2.0.0,>=1.40.0->langchain-openai) (4.4.0)
# Collecting distro<2,>=1.7.0 (from openai<2.0.0,>=1.40.0->langchain-openai)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from openai<2.0.0,>=1.40.0->langchain-openai) (0.27.2)
# Collecting jiter<1,>=0.4.0 (from openai<2.0.0,>=1.40.0->langchain-openai)
#   Downloading jiter-0.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Requirement already satisfied: sniffio in /srv/conda/envs/notebook/lib/python3.10/site-packages (from openai<2.0.0,>=1.40.0->langchain-openai) (1.3.1)
# Collecting tqdm>4 (from openai<2.0.0,>=1.40.0->langchain-openai)
#   Downloading tqdm-4.66.5-py3-none-any.whl.metadata (57 kB)
# Collecting regex>=2022.1.18 (from tiktoken<1,>=0.7->langchain-openai)
#   Downloading regex-2024.7.24-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
# Requirement already satisfied: requests>=2.26.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from tiktoken<1,>=0.7->langchain-openai) (2.32.3)
# Requirement already satisfied: idna>=2.8 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.40.0->langchain-openai) (3.8)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.40.0->langchain-openai) (1.2.2)
# Requirement already satisfied: certifi in /srv/conda/envs/notebook/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.40.0->langchain-openai) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in /srv/conda/envs/notebook/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.40.0->langchain-openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.40.0->langchain-openai) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.35->langchain-openai) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.3.0,>=0.2.35->langchain-openai) (3.10.7)
# Requirement already satisfied: annotated-types>=0.4.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pydantic<3,>=1->langchain-core<0.3.0,>=0.2.35->langchain-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pydantic<3,>=1->langchain-core<0.3.0,>=0.2.35->langchain-openai) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (2.2.2)
# Downloading langchain_openai-0.1.23-py3-none-any.whl (51 kB)
# Downloading openai-1.44.0-py3-none-any.whl (367 kB)
# Downloading tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 8.6 MB/s eta 0:00:00
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading jiter-0.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (318 kB)
# Downloading regex-2024.7.24-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (776 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 776.5/776.5 kB 6.4 MB/s eta 0:00:00
# Downloading tqdm-4.66.5-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, regex, jiter, distro, tiktoken, openai, langchain-openai
# Successfully installed distro-1.9.0 jiter-0.5.0 langchain-openai-0.1.23 openai-1.44.0 regex-2024.7.24 tiktoken-0.7.0 tqdm-4.66.5
# Note: you may need to restart the kernel to use updated packages.

# %%
import dotenv
dotenv.load_dotenv()

# %%
from langchain_openai import ChatOpenAI

# %%
from langchain_core.prompts import ChatPromptTemplate
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a world class technical documentation writer."),
    ("user", "{input}")
])

# %%
chain = prompt | llm

# %%
llm.invoke("how can langsmith help with testing?")
# Out:
# AIMessage(content='Langsmith can help with testing by providing automated testing tools that can help streamline the testing process and improve efficiency. These tools can help identify bugs and errors in the code, as well as track changes and updates to ensure that the software is functioning correctly. Langsmith can also provide testing services, such as test case creation and execution, to help ensure that the software meets the desired quality standards. Additionally, Langsmith can offer expertise in testing methodologies and best practices to help improve the overall testing process.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 99, 'prompt_tokens': 15, 'total_tokens': 114}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-ec909c37-c107-4709-b770-0dcaa6c975be-0', usage_metadata={'input_tokens': 15, 'output_tokens': 99, 'total_tokens': 114})
